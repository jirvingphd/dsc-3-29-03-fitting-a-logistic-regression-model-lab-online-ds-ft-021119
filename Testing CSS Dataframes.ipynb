# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# ### Code for stylized CSS dataframes
# CSS = """
# table.dataframe {
#     border-collapse: collapse;
#     background-color: gainsboro; /* This is alternate rows*/
#     text-align: center;
#     border: 1px solid black;
# }
# table.dataframe tr:not(:last-child) {
#     border-bottom: 1px solid lightgray;
# }
# table.dataframe td, table.dataframe th { /* This is for the borders for columns)*/
#     /*margin: 0.1em;*/
#     /*border: 0.2px solid lightslategray; */
#     /*border:#C7C7C7*/
# /*    padding-left: 0.5em; /*Padding index , header
#     padding-right: 0.5em; /*Padding index , header*/
# /*    padding-top: 0.5em;
#     padding-bottom:0.5em;*/

# }

# table.dataframe th {
#     /*padding:1em 1em;*/
#     background-color: #000000;
#     color: #ffffff;
#     text-align: center;
#     font-weight: bold;
#     font-size: 12pt
#     font-weight: bold;
#     padding: 0.5em 0.5em

# }
# table.dataframe th:not(:empty) {

#     background-color: #000000;
#     color: #ffffff;
#     text-align: center;
#     font-weight: bold;
#     font-size: 12pt
#     padding: 0.7em;

# }
# /*table.dataframe th:empty {
    
#     background-color: #000000;
#     color: #ffffff;
#     text-align: center;
#     vertical-align: middle;

#     font-weight: bold;
# }*/
# /*table.dataframe tr:nth-child(2) th:empty {
#     /*border-left: none;
#     /*border-right: 1px dashed #888;
# }*/
# table.dataframe td {
#     /*border: 1px solid ##e8e8ea;*/
#     /*background-color: ##e8e8ea;*/
#     background-color: ##lightgray;
#     text-align: center; 
#     vertical-align: middle;
#     /*font-size:10pt;*/
#     padding: 0.7em 1em;
#     /*padding: 0.1em 0.1em;*/
# }
# table.dataframe td, table.dataframe.
# """

# %%
import pandas as pd
import numpy as np
cols = ['test','ing','css']
test = np.random.randn(3,10)
df = pd.DataFrame(test.T,columns=cols)

# %%
CSSdf = """
table.dataframe td, table.dataframe th { /* This is for the borders for columns)*/
    border: 2px solid black
    border-collapse:collapse;
}
table.dataframe th {
    /*padding:1em 1em;*/
    background-color: #000000;
    color: #ffffff;
    text-align: center;
    font-weight: bold;
    font-size: 12pt
    font-weight: bold;
    padding: 0.7em 1em
}
table.dataframe td:not(:th){
    /*border: 1px solid ##e8e8ea;*/
    /*background-color: ##e8e8ea;*/
    background-color: ##gainsboro;
    text-align: center; 
    vertical-align: middle;
    font-size:10pt;
    padding: 0.7em 1em;
    /*padding: 0.1em 0.1em;*/
}
table.dataframe tr:not(:last-child) {
    border-bottom: 1px solid gainsboro;
}
table.dataframe {
    /*border-collapse: collapse;*/
    background-color: gainsboro; /* This is alternate rows*/
    text-align: center;
    border: 2px solid black;
}
table.dataframe th:not(:empty), table.dataframe td{
    border-right: 1px solid white;
    text-align: center;
}
"""

# %%
# from IPython.core import display
from IPython.core.display import HTML
from IPython.display import display
# f = open('CSS.css','r')
# f = open('CSS_WIP.css')
HTML('<style>{}</style>'.format(CSSdf))
# Out:
# <style>
# table.dataframe td, table.dataframe th { /* This is for the borders for columns)*/
#     border: 2px solid black
#     border-collapse:collapse;
# }
# table.dataframe th {
#     /*padding:1em 1em;*/
#     background-color: #000000;
#     color: #ffffff;
#     text-align: center;
#     font-weight: bold;
#     font-size: 12pt
#     font-weight: bold;
#     padding: 0.7em 1em
# }
# table.dataframe td:not(:th){
#     /*border: 1px solid ##e8e8ea;*/
#     /*background-color: ##e8e8ea;*/
#     background-color: ##gainsboro;
#     text-align: center;
#     vertical-align: middle;
#     font-size:10pt;
#     padding: 0.7em 1em;
#     /*padding: 0.1em 0.1em;*/
# }
# table.dataframe tr:not(:last-child) {
#     border-bottom: 1px solid gainsboro;
# }
# table.dataframe {
#     /*border-collapse: collapse;*/
#     background-color: gainsboro; /* This is alternate rows*/
#     text-align: center;
#     border: 2px solid black;
# }
# table.dataframe th:not(:empty), table.dataframe td{
#     border-right: 1px solid white;
#     text-align: center;
# }
# </style>

# %%
df
# Out:
#        test       ing       css
# 0 -0.213794 -0.813312  0.708897
# 1  0.517544 -1.238365 -1.146981
# 2 -0.409615 -1.512327 -1.690791
# 3 -1.638970 -0.007283 -1.545411
# 4 -0.875467 -0.718470 -0.851069
# 5 -0.748058  2.008084  1.584419
# 6 -1.078854  0.380298 -0.812683
# 7 -0.664922  0.961712  2.021797
# 8 -1.567548  0.290721  1.434294
# 9 -0.707524 -1.059106 -0.840342
